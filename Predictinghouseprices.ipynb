# %% [markdown]
# <a href="https://colab.research.google.com/github/wcolglazier/CTSC_1HR_Class/blob/master/Predictinghouseprices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Using AI to predict house prices**  <!-- Largest size -->

# %% [markdown]
# ![modern-street-with-various-houses-front-view-vector-47819267.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
import pandas as pd

# Feature columns: Size (sq ft), Bedrooms, Bathrooms, Distance to City Center (miles)
features = np.array([
    [1500, 3, 2, 5],
    [1800, 4, 3, 3],
    [1200, 2, 1, 10],
    [2000, 4, 2, 2],
    [850, 1, 1, 15],
    [1600, 3, 2, 6],
    [2200, 5, 3, 1],
    [1400, 3, 2, 8],
    [950, 2, 1, 12],
    [1750, 4, 3, 4],
])

# Target column: Price in $1000s
prices = np.array([350, 450, 200, 500, 120, 360, 600, 280, 150, 420])

# Create a DataFrame for better visualization
data = pd.DataFrame(features, columns=["Size (sq ft)", "Bedrooms", "Bathrooms", "Distance to City Center"])
data["Price ($1000s)"] = prices

# Display the data
print(data)
# %cd /content/Additional-AI-Class-Content
# !git remote add origin git@github.com:wcolglazier/Additional-AI-Class-Content.git
# !git branch -M main
# !git add .
# !git commit -m "Initial commit with AI class content"
# !git push -u origin main
# Out:
#    Size (sq ft)  Bedrooms  Bathrooms  Distance to City Center  Price ($1000s)
# 0          1500         3          2                        5             350
# 1          1800         4          3                        3             450
# 2          1200         2          1                       10             200
# 3          2000         4          2                        2             500
# 4           850         1          1                       15             120
# 5          1600         3          2                        6             360
# 6          2200         5          3                        1             600
# 7          1400         3          2                        8             280
# 8           950         2          1                       12             150
# 9          1750         4          3                        4             420
# /content/Additional-AI-Class-Content
# error: remote origin already exists.
# On branch main
#
# Initial commit
#
# ...

# %%
# %cd /content/Additional-AI-Class-Content
# !git remote add origin git@github.com:wcolglazier/Additional-AI-Class-Content.git
# !git branch -M main
# !git add .
# !git commit -m "Initial commit with AI class content"
# !git push -u origin main
# Out:
# /content/Additional-AI-Class-Content
# error: remote origin already exists.
# On branch main
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/wcolglazier/Additional-AI-Class-Content.git'
